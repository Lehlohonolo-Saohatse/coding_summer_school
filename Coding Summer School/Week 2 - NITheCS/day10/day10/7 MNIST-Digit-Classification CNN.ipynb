# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
#adopted from:
#https://github.com/csbanon/mnist-classifiers/blob/main/mnist-digits/mnist-digit-classification-with-a-convolutional-neural-network.ipynb

# %%
# Load the MNIST dataset.
mnist = tf.keras.datasets.mnist
train_data, test_data = mnist.load_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Load the MNIST dataset.
# ----> 2 mnist = tf.keras.datasets.mnist
#       3 train_data, test_data = mnist.load_data()
#
# NameError: name 'tf' is not defined

# %%
#train_data[0][0]
#train_data[1][0]

# %%
# Divide the data into features and labels.
train_images, train_labels = train_data
test_images, test_labels = test_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Divide the data into features and labels.
# ----> 2 train_images, train_labels = train_data
#       3 test_images, test_labels = test_data
#
# NameError: name 'train_data' is not defined

# %%
# Reshape and normalize the images.
X_train = train_images.reshape((60000, 28, 28, 1))
X_train = X_train.astype('float32') / 255
X_test = test_images.reshape((10000, 28, 28, 1))
X_test = X_test.astype('float32') / 255
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Reshape and normalize the images.
# ----> 2 X_train = train_images.reshape((60000, 28, 28, 1))
#       3 X_train = X_train.astype('float32') / 255
#       4 X_test = test_images.reshape((10000, 28, 28, 1))
#
# NameError: name 'train_images' is not defined

# %%
# Reshape the labels and encode them categorically.
y_train = tf.keras.utils.to_categorical(train_labels)
y_test = tf.keras.utils.to_categorical(test_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Reshape the labels and encode them categorically.
# ----> 2 y_train = tf.keras.utils.to_categorical(train_labels)
#       3 y_test = tf.keras.utils.to_categorical(test_labels)
#
# NameError: name 'tf' is not defined

# %%
# Show the shapes of the data.
print("Training Images:", X_train.shape)
print("Testing Images:", X_test.shape)
print("Training Labels:", y_train.shape)
print("Test Labels:", y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Show the shapes of the data.
# ----> 2 print("Training Images:", X_train.shape)
#       3 print("Testing Images:", X_test.shape)
#       4 print("Training Labels:", y_train.shape)
#
# NameError: name 'X_train' is not defined

# %%
# Show a sample MNIST digit.
plt.imshow(train_images[40], cmap=plt.get_cmap('gray'))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Show a sample MNIST digit.
# ----> 2 plt.imshow(train_images[40], cmap=plt.get_cmap('gray'))
#       3 plt.show()
#
# NameError: name 'train_images' is not defined

# %%
#we can do it better;)
for i in range(9): 
    plt.subplot(330 + 1 + i)
    plt.imshow(train_images[i], cmap=plt.get_cmap('gray'))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       2 for i in range(9):
#       3     plt.subplot(330 + 1 + i)
# ----> 4     plt.imshow(train_images[i], cmap=plt.get_cmap('gray'))
#       5 plt.show()
#
# NameError: name 'train_images' is not defined

# %%
# Define the sequential model.
model = tf.keras.models.Sequential()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Define the sequential model.
# ----> 2 model = tf.keras.models.Sequential()
#
# NameError: name 'tf' is not defined

# %%
# Define the convolutional neural network.
model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(2, 2))
model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Define the convolutional neural network.
# ----> 2 model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
#       3 model.add(tf.keras.layers.MaxPooling2D((2, 2)))
#       4 model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))
#
# NameError: name 'model' is not defined

# %%
# Show the model.
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Show the model.
# ----> 2 model.summary()
#
# NameError: name 'model' is not defined

# %%
# Compile the model.
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Define the parameters.
num_epochs = 10
batch_size = 128

# Train the model.
history = model.fit(X_train, 
                      y_train, 
                      epochs=num_epochs, 
                      batch_size=batch_size, 
                      validation_data=(X_test, y_test))

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print('Test Accuracy:', test_accuracy)
print('Test Loss:', test_loss)

# %%
# Save the metrics.
metrics = history.history

# %%
# Save the loss values.
training_loss_list = metrics['loss']
test_loss_list = metrics['val_loss']

# %%
# Plot the training and test loss.
x = np.arange(0, num_epochs, 1)
plt.title('Training and Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(x, training_loss_list, label='Training Loss')
plt.plot(x, test_loss_list, label='Test Loss')
plt.legend()
plt.show()

# %%
train_accuracy_list = metrics['accuracy']
test_accuracy_list = metrics['val_accuracy']

# %%
plt.title('Training and Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.plot(x, train_accuracy_list, label='Training Accuracy')
plt.plot(x, test_accuracy_list, label='Test Accuracy')
plt.legend()
plt.show()

# %%
# Make predictions with the trained model.
predictions = model.predict(X_test)

# %%
# Choose an index.
index = 120

# Show an image from the test set.
plt.imshow(test_images[index], cmap=plt.get_cmap('gray'))
plt.show()

# %%
print("Prediction:", np.argmax(predictions[index]))
